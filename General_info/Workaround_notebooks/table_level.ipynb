# %%
import pandas as pd
import numpy as np
import json

# %%
data_path = "./data/HealthCare_Gold_datasets/Context/full_role_based_metric_access.json"
with open(data_path, "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)

# %%
non_clinical_staff_df = df['non_clinical_staff']['metrics']
manager_df = df['managers']['metrics']
admin_df = df['administrative_staff']['metrics']
## Join non_clinical staff with manager and admin metrics
non_clinical_staff_df = pd.DataFrame(non_clinical_staff_df)
manager_df = pd.DataFrame(manager_df)
admin_df = pd.DataFrame(admin_df)
# Merging non-clinical staff metrics with manager and admin metrics
merged_df = pd.concat([non_clinical_staff_df, manager_df, admin_df], ignore_index=True)
# Display the merged DataFrame
merged_df.head()
# Out:
#                       Column Name Data Type  \
# 0   patient_arrival_count_monthly     int64
# 1     patient_arrival_count_daily    object
# 2            bed_utilization_rate   float64
# 3          staff_utilization_rate   float64
# 4  outpatient_visit_count_monthly       int
#
#                                       Description     Granularity  \
# 0   Total number of patient arrivals in the month         Monthly
# 1   Daily count of patient arrivals (JSON format)  Daily (nested)
# 2              Emergency bed utilization rate (%)         Monthly
# 3                   ED staff utilization rate (%)         Monthly
# 4  Total number of outpatient visits in the month         Monthly
#
#                                          Calculation  \
# 0              Sum of patient arrivals for the month
# 1  Aggregated from daily patient logs, may includ...
# 2                   (Beds in Use / Total Beds) * 100
# 3                 (Staff in Use / Total Staff) * 100
# 4               Sum of daily outpatient visit counts
#
#                     source_sheet
# 0   emergency_department_metrics
# 1   emergency_department_metrics
# 2   emergency_department_metrics
# 3   emergency_department_metrics
# 4  outpatient_department_metrics

# %%
non_clinical_staff_df['role'] = 'non_clinical_staff'
manager_df['role'] = 'manager'
admin_df['role'] = 'administrative_staff'
# Concatenate the DataFrames
all_roles_df = pd.concat([non_clinical_staff_df, manager_df, admin_df], ignore_index=True)

# %%
# add records with table name and "manager" role
new_rows = pd.DataFrame([{'source_sheet': 'departments', 'role': ['manager','administrative_staff']},
                        {'source_sheet': 'staff', 'role': ['manager','administrative_staff']},
                        {'source_sheet': 'hospitals', 'role': ['manager','administrative_staff']}])

# Append the new row to the original DataFrame
all_roles_df = pd.concat([all_roles_df, new_rows], ignore_index=True)

# %%
# If any 'role' is a list, explode it so each role is in its own row
all_roles_exploded = all_roles_df.explode('role')

# Now group by 'source_sheet' and get unique roles as a list
unique_combination = all_roles_exploded.groupby('source_sheet')['role'].unique().reset_index()
unique_combination.columns = ['source_sheet', 'roles']

# Display the unique combinations DataFrame
unique_combination
# Out:
#                      source_sheet  \
# 0          administration_metrics
# 1                     icu_metrics
# 2                     departments
# 3    emergency_department_metrics
# 4         finance_billing_metrics
# 5                       hospitals
# 6          inpatient_ward_metrics
# 7   laboratory_department_metrics
# 8   outpatient_department_metrics
# 9      patient_experience_metrics
# 10    pharmacy_department_metrics
# 11         quality_safety_metrics
# 12   radiology_department_metrics
# 13                          staff
# 14     surgery_department_metrics
#
#                                                 roles
# 0                     [manager, administrative_staff]
# 1                     [manager, administrative_staff]
# 2                     [manager, administrative_staff]
# 3   [non_clinical_staff, manager, administrative_s...
# 4                       [non_clinical_staff, manager]
# 5                     [manager, administrative_staff]
# 6                     [manager, administrative_staff]
# 7                       [non_clinical_staff, manager]
# 8   [non_clinical_staff, manager, administrative_s...
# 9                     [manager, administrative_staff]
# 10                    [manager, administrative_staff]
# 11  [non_clinical_staff, manager, administrative_s...
# 12  [non_clinical_staff, manager, administrative_s...
# 13                    [manager, administrative_staff]
# 14  [non_clinical_staff, manager, administrative_s...

# %%
keys_req = ["table_name","description","joins"]

table_name_mapping = {
 'departments':'departments',
 'staff':'staff',
 'hospitals':'hospitals',
 'emergency_department_metrics':'emergency_metrics',
 'inpatient_ward_metrics': 'inpatient_metrics',
 'outpatient_department_metrics': 'outpatient_metrics',
 'surgery_department_metrics': 'surgery_metrics',
 'radiology_department_metrics': 'radiology_metrics',
 'laboratory_department_metrics': 'lab_metrics',
 'pharmacy_department_metrics': 'pharmacy_metrics',
 'icu_metrics': 'icu_metrics',
 'administration_metrics': 'hospital_administration_metrics',
 'quality_safety_metrics': 'patient_safety_metrics',
 'finance_billing_metrics' : 'financial_metrics',
 'patient_experience_metrics': 'patient_experience_metrics'}

table_name_mapping_reversed = {
    'departments': 'departments',
    'staff': 'staff',
    'hospitals': 'hospitals',
    'emergency_metrics': 'emergency_department_metrics',
    'inpatient_metrics': 'inpatient_ward_metrics',
    'outpatient_metrics': 'outpatient_department_metrics',
    'surgery_metrics': 'surgery_department_metrics',
    'radiology_metrics': 'radiology_department_metrics',
    'lab_metrics': 'laboratory_department_metrics',
    'pharmacy_metrics': 'pharmacy_department_metrics',
    'icu_metrics': 'icu_metrics',
    'hospital_administration_metrics': 'administration_metrics',
    'patient_safety_metrics': 'quality_safety_metrics',
    'financial_metrics': 'finance_billing_metrics',
    'patient_experience_metrics': 'patient_experience_metrics'
}


table_description_mapping = {
    'departments': 'Information about various departments within the healthcare facility.',
    'staff': 'Details about the healthcare staff including roles and responsibilities.',
    'hospitals': 'Information about different hospitals and their facilities.',
    'emergency_department_metrics': 'Metrics related to the emergency department operations and performance.',
    'inpatient_ward_metrics': 'Metrics related to inpatient ward operations and performance.',
    'outpatient_department_metrics': 'Metrics related to outpatient department operations and performance.',
    'surgery_department_metrics': 'Metrics related to surgery department operations and performance.',
    'radiology_department_metrics': 'Metrics related to radiology department operations and performance.',
    'laboratory_department_metrics': 'Metrics related to laboratory department operations and performance.', 
    'pharmacy_department_metrics': 'Metrics related to pharmacy department operations and performance.',
    'icu_metrics': 'Metrics related to intensive care unit operations and performance.',
    'administration_metrics': 'Metrics related to hospital administration operations and performance.',
    'quality_safety_metrics': 'Metrics related to patient safety and quality of care.',
    'finance_billing_metrics': 'Metrics related to financial operations and billing processes.',
    'patient_experience_metrics': 'Metrics related to patient experience and satisfaction.'
}

# %%
non_clinical_meta_path = "./data/HealthCare_Gold_datasets/Context/non_clinical_metrics_metadata.json"
with open(non_clinical_meta_path, "r") as f:
    non_clinical_meta = json.load(f)

# %%
departments_df = pd.read_csv("./data/HealthCare_Gold_datasets/Hospital info/Departments.csv")
hospital_df = pd.read_csv("./data/HealthCare_Gold_datasets/Hospital info/Hospitals.csv")
staff_df = pd.read_csv("./data/HealthCare_Gold_datasets/Hospital info/Staff.csv")


# create a dictionary of table name and description
departments_df['role'] = [['manager', 'administrative_staff'] for _ in range(len(departments_df))]
hospital_df['role'] = [['manager', 'administrative_staff'] for _ in range(len(hospital_df))]
staff_df['role'] = [['manager', 'administrative_staff'] for _ in range(len(staff_df))]

# concatenate the three dataframes and convert to a dictionary
dim_tables = {
    "departments": departments_df.to_dict(orient='records'),
    "hospitals": hospital_df.to_dict(orient='records'),
    "staff": staff_df.to_dict(orient='records')
}

# copy all the key values from non_clinical_meta to dim_tables
for key in non_clinical_meta.keys():
    if key not in dim_tables:
        dim_tables[key] = non_clinical_meta[key]

dim_tables
# Out:
# {'departments': [{'department_id': 'DEPT001',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Aaryahi Chad',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT002',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Shray Korpal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT051',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Neelofar Kaur',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT052',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Ela Master',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT041',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Divyansh Krishnamurthy',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT042',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Dishani Kibe',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT031',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Indrajit Sachar',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT032',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Ira Chowdhury',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT021',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Samiha Sule',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT022',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Saanvi Soman',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT011',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Arnav Yohannan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT012',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Yashvi Buch',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT061',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Kanav Agate',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT062',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Mishti Kota',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT111',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Hridaan Krishnan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT112',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Khushi Agate',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT101',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Kiaan Arya',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT102',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Indrans Goyal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT091',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Jiya Dubey',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT092',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Miraya Iyer',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT081',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Alia Choudhry',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT082',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Khushi Aggarwal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT071',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Misha Manda',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT072',
#    'hospital_id': 'HOSP002',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Shanaya Karpe',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT013',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Khushi Kashyap',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT014',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Kanav Gole',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT003',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Saksham Dhingra',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT004',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Tarini Swamy',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT053',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Prisha Khalsa',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT054',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Madhup Bawa',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT043',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Abram Shroff',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT044',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Myra Kala',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT033',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Purab Mane',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT034',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Hazel Banik',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT023',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Anya Hari',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT024',
#    'hospital_id': 'HOSP003',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Riaan Buch',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT073',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Aradhya Batra',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT074',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Anika Chandran',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT063',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Krish Krishnamurthy',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT064',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Anay Doshi',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT113',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Armaan Sura',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT114',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Zain Agarwal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT103',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Biju Bhatt',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT104',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Dhruv Varty',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT093',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Aayush Bhardwaj',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT094',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ivana Dutta',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT083',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Himmat Chowdhury',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT084',
#    'hospital_id': 'HOSP004',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Myra Chadha',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT025',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Mohanlal Doctor',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT026',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Aniruddh Som',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT015',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Divit Master',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT016',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Rasha Borde',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT005',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Hridaan Barman',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT006',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Hridaan Viswanathan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT055',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Vritika Bail',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT056',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Ivana Vora',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT045',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Amani Warrior',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT046',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Mehul Sanghvi',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT035',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Heer Johal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT036',
#    'hospital_id': 'HOSP005',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Jayan Upadhyay',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT085',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Emir Bora',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT086',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Eva Bala',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT075',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Aarav Dada',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT076',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Anvi Balasubramanian',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT065',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Rania Bala',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT066',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Nitya Chakrabarti',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT115',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Prisha Goda',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT116',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Parinaaz Bhatt',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT105',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ira Majumdar',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT106',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Zaina Date',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT095',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Dharmajan Kashyap',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT096',
#    'hospital_id': 'HOSP006',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Zoya Bandi',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT037',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Ishita Ramachandran',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT038',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Jayesh Chanda',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT027',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Mamooty Hans',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT028',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Mohanlal Varughese',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT017',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Riaan Chowdhury',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT018',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Biju Bava',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT007',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Mannat Bora',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT008',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Inaaya Sankar',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT057',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ayesha Bala',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT058',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Himmat Agarwal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT047',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ishita Sachdev',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT048',
#    'hospital_id': 'HOSP007',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Gokul Dhar',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT097',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Kanav Chopra',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT098',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Sara Bhasin',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT087',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Aniruddh Vyas',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT088',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Elakshi Gopal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT077',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Stuvan Sarraf',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT078',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Tara Verma',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT067',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Uthkarsh Biswas',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT068',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Anika D’Alia',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT117',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ishaan Gokhale',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT118',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Umang Wable',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT107',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Shaan Sahni',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT108',
#    'hospital_id': 'HOSP008',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Neysa Choudhry',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT049',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Mamooty Viswanathan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT050',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Vritika Sampath',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT039',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Zoya Tandon',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT040',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Kabir Mahal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT029',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Romil Viswanathan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT030',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Urvi Srinivas',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT019',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Aradhya Rajan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT020',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Kimaya Wali',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT009',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Seher Sandal',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT010',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Romil Bora',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT059',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Fateh Swamy',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT060',
#    'hospital_id': 'HOSP009',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Purab Sethi',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT109',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Emergency Department',
#    'floor_number': '1',
#    'head_of_department': 'Bhavin Sha',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT110',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Inpatient Ward',
#    'floor_number': '3',
#    'head_of_department': 'Ritvik Agate',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT099',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Outpatient Department',
#    'floor_number': '2',
#    'head_of_department': 'Taimur Ratta',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT100',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Surgery Department',
#    'floor_number': '4',
#    'head_of_department': 'Saksham Hora',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT089',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Radiology Department',
#    'floor_number': '2',
#    'head_of_department': 'Tara Batta',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT090',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Laboratory Department',
#    'floor_number': '1',
#    'head_of_department': 'Dishani Dhar',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT079',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Pharmacy Department',
#    'floor_number': '1',
#    'head_of_department': 'Vivaan Gara',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT080',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Intensive Care Unit (ICU)',
#    'floor_number': '5',
#    'head_of_department': 'Vardaniya Chauhan',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT069',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Administration',
#    'floor_number': 'Ground',
#    'head_of_department': 'Tarini Gour',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT070',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Quality & Safety',
#    'floor_number': 'Ground',
#    'head_of_department': 'Rati Wadhwa',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT119',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Finance & Billing',
#    'floor_number': 'Ground',
#    'head_of_department': 'Ojas Chaudry',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']},
#   {'department_id': 'DEPT120',
#    'hospital_id': 'HOSP010',
#    'department_name': 'Patient Experience',
#    'floor_number': '2',
#    'head_of_department': 'Yuvraj Vyas',
#    'active_status': True,
#    'role': ['manager', 'administrative_staff']}],
#  'hospitals': [{'hospital_id': 'HOSP001',
#    'hospital_name': 'All India Institute of Medical Sciences, Delhi',
#    'address_line': 'Ansari Nagar',
#    'city': 'New Delhi',
#    'state': 'Delhi',
#    'zip_code': 110029,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 2400,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1956-02-01',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP002',
#    'hospital_name': 'Postgraduate Institute of Medical Education and Research',
#    'address_line': 'Sector 12, Chandigarh',
#    'city': 'Chandigarh',
#    'state': 'Punjab',
#    'zip_code': 160012,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 1500,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1962-08-15',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP003',
#    'hospital_name': 'Christian Medical College, Vellore',
#    'address_line': 'Ida Scudder Road',
#    'city': 'Vellore',
#    'state': 'Tamil Nadu',
#    'zip_code': 632004,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 2800,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1900-01-01',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP004',
#    'hospital_name': 'Tata Memorial Hospital',
#    'address_line': 'Dr. E Borges Road',
#    'city': 'Mumbai',
#    'state': 'Maharashtra',
#    'zip_code': 400012,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 550,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1941-12-01',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP005',
#    'hospital_name': "King George's Medical University",
#    'address_line': 'Chowk, Kaiserbagh',
#    'city': 'Lucknow',
#    'state': 'Uttar Pradesh',
#    'zip_code': 226003,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 3200,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1911-01-01',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP006',
#    'hospital_name': 'Sir Ganga Ram Hospital',
#    'address_line': 'Rajinder Nagar',
#    'city': 'New Delhi',
#    'state': 'Delhi',
#    'zip_code': 110060,
#    'country': 'India',
#    'hospital_type': 'General',
#    'bed_capacity': 650,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1921-06-15',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP007',
#    'hospital_name': 'Apollo Hospitals',
#    'address_line': 'Greams Lane',
#    'city': 'Chennai',
#    'state': 'Tamil Nadu',
#    'zip_code': 600006,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 1500,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1983-10-06',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP008',
#    'hospital_name': 'Fortis Memorial Research Institute',
#    'address_line': 'Sector 44',
#    'city': 'Gurgaon',
#    'state': 'Haryana',
#    'zip_code': 122002,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 700,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '2001-11-20',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP009',
#    'hospital_name': 'Medanta - The Medicity',
#    'address_line': 'Sector 38',
#    'city': 'Gurgaon',
#    'state': 'Haryana',
#    'zip_code': 122001,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 1250,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '2009-05-16',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']},
#   {'hospital_id': 'HOSP010',
#    'hospital_name': 'Christian Medical College, Ludhiana',
#    'address_line': 'Govt. Road',
#    'city': 'Ludhiana',
#    'state': 'Punjab',
#    'zip_code': 141008,
#    'country': 'India',
#    'hospital_type': 'Specialty',
#    'bed_capacity': 900,
#    'accreditation': 'NABH Accredited',
#    'opening_date': '1894-01-01',
#    'closing_date': nan,
#    'role': ['manager', 'administrative_staff']}],
#  'staff': [{'staff_id': 'STAF0001',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Prakash',
#    'last_name': 'Agarwal',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Part-time',
#    'hire_date': '26-04-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0002',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Vikram',
#    'last_name': 'Reddy',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '22-04-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0005',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Kavita',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '23-07-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0006',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Vandana',
#    'last_name': 'Jain',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '13-03-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0007',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Seema',
#    'last_name': 'Jain',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Part-time',
#    'hire_date': '20-01-2024',
#    'termination_date': nan},
#   {'staff_id': 'STAF0008',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Neha',
#    'last_name': 'Gupta',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '10-07-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0009',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Tanvi',
#    'last_name': 'Patel',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '11-03-2022',
#    'termination_date': nan},
#   {'staff_id': 'STAF0010',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Manoj',
#    'last_name': 'Joshi',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '10-02-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0011',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Pooja',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '08-11-2015',
#    'termination_date': nan},
#   {'staff_id': 'STAF0012',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Prakash',
#    'last_name': 'Sharma',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '09-09-2021',
#    'termination_date': nan},
#   {'staff_id': 'STAF0013',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Emergency Department',
#    'first_name': 'Manoj',
#    'last_name': 'Agarwal',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '26-04-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0014',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Neha',
#    'last_name': 'Shukla',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '14-07-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0015',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Rajesh',
#    'last_name': 'Agarwal',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '20-06-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0016',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Madhuri',
#    'last_name': 'Malhotra',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '11-03-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0017',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Prakash',
#    'last_name': 'Gupta',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '28-11-2022',
#    'termination_date': nan},
#   {'staff_id': 'STAF0019',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Seema',
#    'last_name': 'Malhotra',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '19-04-2018',
#    'termination_date': nan},
#   {'staff_id': 'STAF0020',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Pooja',
#    'last_name': 'Agarwal',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '05-06-2021',
#    'termination_date': nan},
#   {'staff_id': 'STAF0021',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Kavita',
#    'last_name': 'Joshi',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '04-06-2015',
#    'termination_date': nan},
#   {'staff_id': 'STAF0022',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Manoj',
#    'last_name': 'Reddy',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '02-09-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0023',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Kavita',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Part-time',
#    'hire_date': '20-03-2017',
#    'termination_date': nan},
#   {'staff_id': 'STAF0024',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Vikram',
#    'last_name': 'Reddy',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Part-time',
#    'hire_date': '22-05-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0025',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Seema',
#    'last_name': 'Malhotra',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '10-11-2015',
#    'termination_date': nan},
#   {'staff_id': 'STAF0026',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Vikram',
#    'last_name': 'Patel',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '17-10-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0027',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Rina',
#    'last_name': 'Reddy',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Part-time',
#    'hire_date': '09-09-2015',
#    'termination_date': nan},
#   {'staff_id': 'STAF0028',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Manoj',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '01-09-2022',
#    'termination_date': nan},
#   {'staff_id': 'STAF0029',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Amit',
#    'last_name': 'Yadav',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '12-12-2017',
#    'termination_date': nan},
#   {'staff_id': 'STAF0030',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Ravi',
#    'last_name': 'Jadhav',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '21-11-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0031',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Amit',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '28-01-2022',
#    'termination_date': nan},
#   {'staff_id': 'STAF0032',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Seema',
#    'last_name': 'Gupta',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '27-07-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0033',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Vikram',
#    'last_name': 'Soni',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Full-time',
#    'hire_date': '20-11-2017',
#    'termination_date': nan},
#   {'staff_id': 'STAF0034',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Arvind',
#    'last_name': 'Shukla',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '27-05-2022',
#    'termination_date': nan},
#   {'staff_id': 'STAF0035',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Seema',
#    'last_name': 'Gupta',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '22-07-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0036',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Madhuri',
#    'last_name': 'Sharma',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Full-time',
#    'hire_date': '29-03-2023',
#    'termination_date': nan},
#   {'staff_id': 'STAF0037',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Rina',
#    'last_name': 'Kumar',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Part-time',
#    'hire_date': '15-10-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0038',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Kavita',
#    'last_name': 'Jain',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '26-07-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0039',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Inpatient Ward',
#    'first_name': 'Amit',
#    'last_name': 'Jain',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '05-06-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0040',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Arvind',
#    'last_name': 'Joshi',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Part-time',
#    'hire_date': '12-03-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0041',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Rajesh',
#    'last_name': 'Gupta',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Part-time',
#    'hire_date': '28-05-2017',
#    'termination_date': nan},
#   {'staff_id': 'STAF0042',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Meenal',
#    'last_name': 'Malhotra',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '03-12-2019',
#    'termination_date': nan},
#   {'staff_id': 'STAF0043',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Meenal',
#    'last_name': 'Chauhan',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '18-05-2021',
#    'termination_date': nan},
#   {'staff_id': 'STAF0044',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Anjali',
#    'last_name': 'Rao',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '12-05-2024',
#    'termination_date': nan},
#   {'staff_id': 'STAF0045',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Sandeep',
#    'last_name': 'Kapoor',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '18-11-2016',
#    'termination_date': nan},
#   {'staff_id': 'STAF0046',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Sunil',
#    'last_name': 'Shukla',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'MD',
#    'employment_status': 'Contract',
#    'hire_date': '16-02-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0047',
#    'hospital_id': 'HOSP001',
#    'department_name': 'Outpatient Department',
#    'first_name': 'Sandeep',
#    'last_name': 'Shukla',
#    'role': ['manager', 'administrative_staff'],
#    'credential': 'BSc Nursing',
#    'employment_status': 'Contract',
#    'hire_date': '30-04-2020',
#    'termination_date': nan},
#   {'staff_id': 'STAF0048',
#    'hospital_id': 'HOSP001',
# ...
#    'Calculation': 'Total Time to Report / Number of Tests'},
#   {'Column Name': 'test_error_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of tests with errors',
#    'Granularity': 'Monthly',
#    'Calculation': '(Number of Test Errors / Total Tests) * 100'},
#   {'Column Name': 'critical_value_reporting_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of critical lab values reported within target time',
#    'Granularity': 'Monthly',
#    'Calculation': '(Critical Results Reported on Time / Total Critical Results) * 100'},
#   {'Column Name': 'equipment_downtime_hours',
#    'Data Type': 'float',
#    'Description': 'Total hours lab equipment was non-operational',
#    'Granularity': 'Monthly',
#    'Calculation': 'Sum of downtime incidents for lab equipment'},
#   {'Column Name': 'sample_rejection_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of samples rejected due to quality or procedural issues',
#    'Granularity': 'Monthly',
#    'Calculation': '(Rejected Samples / Total Samples Collected) * 100'},
#   {'Column Name': 'patient_test_coverage_pct',
#    'Data Type': 'float',
#    'Description': 'Percentage of admitted patients who received at least one lab test',
#    'Granularity': 'Monthly',
#    'Calculation': '(Patients Tested / Total Admitted Patients) * 100'}],
#  'pharmacy_department_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'Date of metric measurement',
#    'Granularity': 'Daily',
#    'Calculation': 'Direct from source system'},
#   {'Column Name': 'medication_type',
#    'Data Type': 'object',
#    'Description': 'Category/type of medication dispensed (e.g., ORAL, INJ, ONC)',
#    'Granularity': 'Medication-type level',
#    'Calculation': 'Direct from source system'},
#   {'Column Name': 'dispensing_error_rate',
#    'Data Type': 'float64',
#    'Description': 'Percentage of errors during medication dispensing',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Dispensing Errors / Total Prescriptions) * 100'},
#   {'Column Name': 'inventory_turnover_rate',
#    'Data Type': 'float64',
#    'Description': 'Rate at which inventory is cycled (Inventory Turnover)',
#    'Granularity': 'Medication-type level',
#    'Calculation': 'Cost of Goods Sold / Average Inventory'},
#   {'Column Name': 'generic_medication_usage_pct',
#    'Data Type': 'float64',
#    'Description': 'Percentage of medications dispensed that are generics',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Generic Prescriptions / Total Prescriptions) * 100'},
#   {'Column Name': 'stock_out_rate',
#    'Data Type': 'float64',
#    'Description': 'Percentage of times medication stock was unavailable',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Out of Stock Occurrences / Total Requests) * 100'},
#   {'Column Name': 'avg_dispense_time_min',
#    'Data Type': 'float64',
#    'Description': 'Average time taken to dispense medication (in minutes)',
#    'Granularity': 'Medication-type level',
#    'Calculation': 'Average dispense time per prescription'},
#   {'Column Name': 'protocol_compliance_rate',
#    'Data Type': 'float64',
#    'Description': 'Percentage compliance with pharmacy protocols',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Compliant Transactions / Total Transactions) * 100'},
#   {'Column Name': 'patient_counseling_rate',
#    'Data Type': 'float64',
#    'Description': 'Percentage of patients who received counseling with medication',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Counseled Patients / Total Patients) * 100'},
#   {'Column Name': 'adverse_drug_reaction_rate',
#    'Data Type': 'float64',
#    'Description': 'Percentage of adverse drug reactions reported',
#    'Granularity': 'Medication-type level',
#    'Calculation': '(# Adverse Reactions / Total Medications Dispensed) * 100'}],
#  ' icu_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'The reporting month for ICU metrics',
#    'Granularity': 'Monthly',
#    'Calculation': 'None'},
#   {'Column Name': 'icu_id',
#    'Data Type': 'object',
#    'Description': 'Unique identifier for the ICU unit',
#    'Granularity': 'ICU',
#    'Calculation': 'None'},
#   {'Column Name': 'bed_occupancy_rate_monthly',
#    'Data Type': 'float',
#    'Description': 'Average percentage of occupied ICU beds in the month',
#    'Granularity': 'Monthly',
#    'Calculation': '(Occupied Bed Days / Available Bed Days) * 100'},
#   {'Column Name': 'bed_occupancy_rate_daily',
#    'Data Type': 'object',
#    'Description': 'Dictionary of daily ICU bed occupancy rates',
#    'Granularity': 'Daily(nested)',
#    'Calculation': 'Raw daily occupancy percentages, may include fractional values due to smoothing or averaging'},
#   {'Column Name': 'avg_length_of_stay_days',
#    'Data Type': 'float',
#    'Description': 'Average length of stay in ICU in days',
#    'Granularity': 'Monthly',
#    'Calculation': 'Total ICU Days / Number of Discharges'},
#   {'Column Name': 'ventilator_associated_pneumonia_rate',
#    'Data Type': 'float',
#    'Description': 'Rate of VAP cases per 1,000 ventilator days',
#    'Granularity': 'Monthly',
#    'Calculation': '(VAP Cases / Ventilator Days) * 1000'},
#   {'Column Name': 'icu_mortality_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of ICU patients who died',
#    'Granularity': 'Monthly',
#    'Calculation': '(ICU Deaths / ICU Admissions) * 100'},
#   {'Column Name': 'nurse_to_patient_ratio',
#    'Data Type': 'float',
#    'Description': 'Ratio of nurses to patients in the ICU',
#    'Granularity': 'Monthly',
#    'Calculation': 'Number of Nurses / Number of Patients'},
#   {'Column Name': 'time_to_antibiotic_admin_min',
#    'Data Type': 'float',
#    'Description': 'Average time in minutes to administer antibiotics',
#    'Granularity': 'Monthly',
#    'Calculation': 'Average time from order to administration'},
#   {'Column Name': 'clabsi_rate',
#    'Data Type': 'float',
#    'Description': 'Central line-associated bloodstream infection rate per 1,000 line days',
#    'Granularity': 'Monthly',
#    'Calculation': '(CLABSI Cases / Line Days) * 1000'},
#   {'Column Name': 'icu_readmission_rate_48h',
#    'Data Type': 'float',
#    'Description': 'Percentage of patients readmitted to ICU within 48 hours',
#    'Granularity': 'Monthly',
#    'Calculation': '(ICU Readmissions within 48h / Total Discharges) * 100'},
#   {'Column Name': 'sepsis_screening_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of patients screened for sepsis upon ICU admission',
#    'Granularity': 'Monthly',
#    'Calculation': '(Sepsis Screenings / ICU Admissions) * 100'},
#   {'Column Name': 'apache_ii_score_avg',
#    'Data Type': 'float',
#    'Description': 'Average APACHE II score for ICU patients',
#    'Granularity': 'Monthly',
#    'Calculation': 'Mean of APACHE II scores for all ICU patients'},
#   {'Column Name': 'sofa_score_avg',
#    'Data Type': 'float',
#    'Description': 'Average SOFA score for ICU patients',
#    'Granularity': 'Monthly',
#    'Calculation': 'Mean of SOFA scores for all ICU patients'}],
#  ' administration_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'The reporting month for administrative metrics',
#    'Granularity': 'Monthly',
#    'Calculation': 'None'},
#   {'Column Name': 'hospital_id',
#    'Data Type': 'object',
#    'Description': 'Unique identifier for the hospital or department',
#    'Granularity': 'Hospital',
#    'Calculation': 'None'},
#   {'Column Name': 'revenue_per_patient_day',
#    'Data Type': 'float',
#    'Description': 'Revenue generated per patient per day',
#    'Granularity': 'Monthly',
#    'Calculation': 'Total Revenue / Patient Days'},
#   {'Column Name': 'cost_per_case',
#    'Data Type': 'float',
#    'Description': 'Average cost incurred per case handled',
#    'Granularity': 'Monthly',
#    'Calculation': 'Total Operational Cost / Number of Cases'},
#   {'Column Name': 'staff_turnover_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of staff who left during the period',
#    'Granularity': 'Monthly',
#    'Calculation': '(Number of Departures / Average Staff Count) * 100'},
#   {'Column Name': 'avg_staff_overtime_hours',
#    'Data Type': 'float',
#    'Description': 'Average overtime hours worked per staff member',
#    'Granularity': 'Monthly',
#    'Calculation': 'Total Overtime Hours / Staff Count'},
#   {'Column Name': 'billing_accuracy_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of accurate bills issued',
#    'Granularity': 'Monthly',
#    'Calculation': '(Accurate Bills / Total Bills) * 100'},
#   {'Column Name': 'patient_wait_time_admission',
#    'Data Type': 'float',
#    'Description': 'Average time in minutes patients wait for admission',
#    'Granularity': 'Monthly',
#    'Calculation': 'Average time from registration to admission'},
#   {'Column Name': 'overall_patient_satisfaction',
#    'Data Type': 'float',
#    'Description': 'Average patient satisfaction score (1â€“5 scale)',
#    'Granularity': 'Monthly',
#    'Calculation': 'Survey-based average score'},
#   {'Column Name': 'compliance_audit_score',
#    'Data Type': 'float',
#    'Description': 'Score from internal or external compliance audits',
#    'Granularity': 'Monthly',
#    'Calculation': 'Weighted audit score based on compliance factors'},
#   {'Column Name': 'claims_processing_time_days',
#    'Data Type': 'float',
#    'Description': 'Average number of days to process insurance claims',
#    'Granularity': 'Monthly',
#    'Calculation': 'Total Days to Process / Number of Claims'}],
#  'quality_safety_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'Date of metric measurement',
#    'Granularity': 'Daily',
#    'Calculation': 'Direct from source system'},
#   {'Column Name': 'department_id',
#    'Data Type': 'object',
#    'Description': 'Unique identifier for department',
#    'Granularity': 'Department-level',
#    'Calculation': 'Direct from source system'},
#   {'Column Name': 'patient_safety_incidents',
#    'Data Type': 'int64',
#    'Description': 'Number of reported patient safety incidents',
#    'Granularity': 'Department-level',
#    'Calculation': 'Total safety incidents logged per department'},
#   {'Column Name': 'falls_rate_per_1000_patient_days',
#    'Data Type': 'float64',
#    'Description': 'Number of patient falls per 1,000 patient-days',
#    'Granularity': 'Department-level',
#    'Calculation': '(# Falls / Patient Days) * 1000'},
#   {'Column Name': 'pressure_ulcer_incidence',
#    'Data Type': 'float64',
#    'Description': 'Incidence rate of pressure ulcers in the department',
#    'Granularity': 'Department-level',
#    'Calculation': '(# Pressure Ulcer Cases / Patient Population) * 100'},
#   {'Column Name': 'medication_error_count',
#    'Data Type': 'int64',
#    'Description': 'Number of medication errors reported',
#    'Granularity': 'Department-level',
#    'Calculation': 'Count of reported medication errors'},
#   {'Column Name': 'hand_hygiene_compliance_pct',
#    'Data Type': 'float64',
#    'Description': 'Percentage compliance with hand hygiene protocols',
#    'Granularity': 'Department-level',
#    'Calculation': '(# Compliant Observations / Total Observations) * 100'},
#   {'Column Name': 'patient_complaints_count',
#    'Data Type': 'int64',
#    'Description': 'Number of formal patient complaints received',
#    'Granularity': 'Department-level',
#    'Calculation': 'Count of formal complaints by patients'},
#   {'Column Name': 'staff_training_completion_pct',
#    'Data Type': 'float64',
#    'Description': 'Percentage of staff who completed safety training',
#    'Granularity': 'Department-level',
#    'Calculation': '(# Staff Completed Training / Total Staff) * 100'},
#   {'Column Name': 'safety_audit_score',
#    'Data Type': 'float64',
#    'Description': 'Score from internal safety audit (out of 100)',
#    'Granularity': 'Department-level',
#    'Calculation': 'Average score from safety compliance audits'}],
#  'finance_billing_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'The reporting month for financial metrics',
#    'Granularity': 'Monthly',
#    'Calculation': 'None'},
#   {'Column Name': 'hospital_id',
#    'Data Type': 'object',
#    'Description': 'Unique identifier for the hospital or department',
#    'Granularity': 'Hospital',
#    'Calculation': 'None'},
#   {'Column Name': 'total_revenue',
#    'Data Type': 'float',
#    'Description': 'Total revenue generated in the month',
#    'Granularity': 'Monthly',
#    'Calculation': 'Sum of all revenue streams (billing, insurance, etc.)'},
#   {'Column Name': 'accounts_receivable_days',
#    'Data Type': 'int',
#    'Description': 'Average number of days to collect payment',
#    'Granularity': 'Monthly',
#    'Calculation': '(Accounts Receivable / Average Daily Revenue)'},
#   {'Column Name': 'denial_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of claims denied by insurers',
#    'Granularity': 'Monthly',
#    'Calculation': '(Number of denied claims / Total claims) * 100'},
#   {'Column Name': 'avg_cost_per_procedure',
#    'Data Type': 'float',
#    'Description': 'Average cost incurred per medical procedure',
#    'Granularity': 'Monthly',
#    'Calculation': '(Total cost / Number of procedures)'},
#   {'Column Name': 'insurance_claim_approval_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of insurance claims approved',
#    'Granularity': 'Monthly',
#    'Calculation': '(Approved claims / Submitted claims) * 100'},
#   {'Column Name': 'collection_rate',
#    'Data Type': 'float',
#    'Description': 'Percentage of total revenue successfully collected',
#    'Granularity': 'Monthly',
#    'Calculation': '(Collected Revenue / Billed Revenue) * 100'},
#   {'Column Name': 'expense_ratio',
#    'Data Type': 'float',
#    'Description': 'Proportion of expenses relative to revenue',
#    'Granularity': 'Monthly',
#    'Calculation': '(Total Expenses / Total Revenue)'},
#   {'Column Name': 'budget_variance',
#    'Data Type': 'float',
#    'Description': 'Difference between actual and budgeted expenses',
#    'Granularity': 'Monthly',
#    'Calculation': '(Actual Expense - Budgeted Expense) / Budgeted Expense'}],
#  'patient_experience_metrics': [{'Column Name': 'date',
#    'Data Type': 'object',
#    'Description': 'Date of the recorded metrics',
#    'Granularity': 'Daily',
#    'Calculation': 'Direct entry or calculated based on survey results'},
#   {'Column Name': 'hospital_id',
#    'Data Type': 'object',
#    'Description': 'Unique identifier for the hospital',
#    'Granularity': 'Hospital-level',
#    'Calculation': 'Direct entry'},
#   {'Column Name': 'net_promoter_score',
#    'Data Type': 'float64',
#    'Description': 'Net Promoter Score indicating likelihood of patient recommendation (0-100)',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Derived from patient survey responses'},
#   {'Column Name': 'patient_satisfaction_score',
#    'Data Type': 'float64',
#    'Description': 'Overall patient satisfaction score (typically on a scale of 1 to 5)',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Aggregated average score from surveys'},
#   {'Column Name': 'avg_resolution_time_hours',
#    'Data Type': 'float64',
#    'Description': 'Average time taken to resolve patient issues (in hours)',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Calculated as average resolution time per case'},
#   {'Column Name': 'patient_recommendation_pct',
#    'Data Type': 'float64',
#    'Description': 'Percentage of patients who would recommend the hospital',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Calculated from survey data on patient recommendations'},
#   {'Column Name': 'avg_response_time_minutes',
#    'Data Type': 'float64',
#    'Description': 'Average time taken to respond to patient inquiries (in minutes)',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Average time from issue raised to first response'},
#   {'Column Name': 'patient_education_completion_pct',
#    'Data Type': 'float64',
#    'Description': 'Percentage of patients who completed educational materials',
#    'Granularity': 'Hospital-level daily',
#    'Calculation': 'Percentage of patients who completed assigned educational content'}]}

# %%
# dep_cols = departments_df.columns.tolist()
# hosp_cols = hospital_df.columns.tolist()
# staff_cols = staff_df.columns.tolist()
# # concatenate the columns of the three dataframes
# all_cols = dep_cols + hosp_cols + staff_cols
# all_cols

# %%
# emergency_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/emergency_metrics.csv")
# inpatient_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/inpatient_metrics.csv")
# outpatient_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/outpatient_metrics.csv")
# surgery_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/surgery_metrics.csv")
# radiology_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/radiology_metrics.csv")
# lab_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/lab_metrics.csv")
# pharmacy_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/pharmacy_metrics.csv") 
# icu_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/icu_metrics.csv")
# hospital_administration_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/hospital_administration_metrics.csv")
# patient_safety_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/patient_safety_metrics.csv")
# finance_billing_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/financial_metrics.csv")
# patient_experience_metrics_df = pd.read_csv("./data/HealthCare_Gold_datasets/Non-Clinical KPIs/patient_experience_metrics.csv")

# # get the columns of each dataframe
# emergency_cols = emergency_metrics_df.columns.tolist()
# inpatient_cols = inpatient_metrics_df.columns.tolist()      
# outpatient_cols = outpatient_metrics_df.columns.tolist()
# surgery_cols = surgery_metrics_df.columns.tolist()
# radiology_cols = radiology_metrics_df.columns.tolist()
# lab_cols = lab_metrics_df.columns.tolist()
# pharmacy_cols = pharmacy_metrics_df.columns.tolist()
# icu_cols = icu_metrics_df.columns.tolist()
# hospital_administration_cols = hospital_administration_metrics_df.columns.tolist()
# quality_safety_cols = patient_safety_metrics_df.columns.tolist()
# finance_billing_cols = finance_billing_metrics_df.columns.tolist()
# patient_experience_cols = patient_experience_metrics_df.columns.tolist()
# # concatenate the columns of each dataframe
# all_non_clinical_cols = (emergency_cols + inpatient_cols + outpatient_cols + surgery_cols + 
#                          radiology_cols + lab_cols + pharmacy_cols + icu_cols + 
#                          hospital_administration_cols + quality_safety_cols + 
#                          finance_billing_cols + patient_experience_cols)
# all_non_clinical_cols

# %%
# # get the columns from departments
# departments_columns = departments_df.columns.tolist()
# hospital_columns = hospital_df.columns.tolist()
# staff_columns = staff_df.columns.tolist()
# # map the department columns with the columns in the all_roles_df to get the roles allowed
# def map_roles_to_columns(columns, all_roles_df):
#     roles_allowed = []
#     for column in columns:
#         roles = all_roles_df[all_roles_df['Column Name'] == column]['role'].values
#         if len(roles) > 0:
#             roles_allowed.append(roles[0])
#         else:
#             roles_allowed.append([])
#     return roles_allowed
# dep_mapped_roles = map_roles_to_columns(departments_columns, all_roles_df)
# hospital_mapped_roles = map_roles_to_columns(hospital_columns, all_roles_df)
# staff_mapped_roles = map_roles_to_columns(staff_columns, all_roles_df)

# print("dep_mapped_roles:",dep_mapped_roles)
# print("hospital_mapped_roles:",hospital_mapped_roles)
# print("staff_mapped_roles:",staff_mapped_roles)

# %%
# join_metadata = {
#     "emergency_department_metrics": "departments.department_id",
#     "inpatient_ward_metrics": "departments.department_id → inpatient_metrics.ward_id",
#     "outpatient_department_metrics": "departments.department_id → outpatient_metrics.clinic_id",
#     "surgery_department_metrics": "departments.department_id → surgery_metrics.surgery_type_id",
#     "radiology_department_metrics": None,
#     "laboratory_department_metrics": None,
#     "pharmacy_department_metrics": None,
#     "icu_metrics": "departments.department_id → icu_metrics.icu_id",
#     "administration_metrics": "hospitals.hospital_id",
#     "quality_safety_metrics": "departments.department_id",
#     "finance_billing_metrics": "hospitals.hospital_id",
#     "patient_experience_metrics": "hospitals.hospital_id"
# }

# %%
join_metadata = {
    "emergency_department_metrics": [{"departments.department_id": "emergency_metrics.department_id"}],
    "inpatient_ward_metrics": [{"departments.department_id": "inpatient_metrics.ward_id"}],
    "outpatient_department_metrics": [{"departments.department_id": "outpatient_metrics.clinic_id"}],
    "surgery_department_metrics": [],
    "radiology_department_metrics": [],
    "laboratory_department_metrics": [],
    "pharmacy_department_metrics": [],
    "icu_metrics": [{"departments.department_id": "icu_metrics.icu_id"}],
    "administration_metrics": [{"departments.department_id": "hospital_administration_metrics.hospital_id"}],
    "quality_safety_metrics": [{"departments.department_id": "patient_safety_metrics.department_id"}],
    "finance_billing_metrics": [{"hospitals.hospital_id": "financial_metrics.hospital_id"}],
    "patient_experience_metrics": [{"hospitals.hospital_id": "patient_experience_metrics.hospital_id"}],

    "departments": [{"departments.department_id": "emergency_metrics.department_id"},
                    {"departments.department_id": "inpatient_metrics.ward_id"},
                    {"departments.department_id": "outpatient_metrics.clinic_id"},
                    {"departments.department_id": "icu_metrics.icu_id"},
                    {"departments.department_id": "hospital_administration_metrics.hospital_id"},
                    {"departments.department_id": "patient_safety_metrics.department_id"},
                    {"departments.hospital_id": "hospitals.hospital_id"}],
    "hospitals": [{"hospitals.hospital_id": "financial_metrics.hospital_id"},
                   {"hospitals.hospital_id": "patient_experience_metrics.hospital_id"},
                   {"hospitals.hospital_id": "departments.hospital_id"}],
    "staff": [{"staff.hospital_id": "hospitals.hospital_id"}]
}

# %%
primary_key_metadata = {
    "emergency_department_metrics": [{"primary_key": ["department_id", "date"]}],
    "inpatient_ward_metrics": [{"primary_key": ["ward_id", "date"]}],
    "outpatient_department_metrics": [{"primary_key": ["clinic_id", "date"]}],
    "surgery_department_metrics": [{"primary_key": ["surgery_type_id", "date"]}],
    "radiology_department_metrics": [{"primary_key": ["radiology_lab_id", "date"]}],
    "laboratory_department_metrics": [{"primary_key": ["lab_id", "date"]}],
    "pharmacy_department_metrics": [{"primary_key": ["pharmacy_id", "date"]}],
    "icu_metrics": [{"primary_key": ["icu_id", "date"]}],
    "administration_metrics": [{"primary_key": ["hospital_id", "date"]}],
    "quality_safety_metrics": [{"primary_key": ["department_id", "date"]}],
    "finance_billing_metrics": [{"primary_key": ["hospital_id", "date"]}],
    "patient_experience_metrics": [{"primary_key": ["hospital_id", "date"]}],

    "departments": [{"primary_key": "department_id"}],
    "hospitals": [{"primary_key": "hospital_id"}],
    "staff": [{"primary_key": "staff_id"}]  # Assumed based on naming
}

# %%
foreign_key_metadata = {
    "emergency_department_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "department_id"}}
    ],
    "inpatient_ward_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "ward_id"}}
    ],
    "outpatient_department_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "clinic_id"}}
    ],
    "surgery_department_metrics": [],
    "radiology_department_metrics": [],
    "laboratory_department_metrics": [],
    "pharmacy_department_metrics": [],
    "icu_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "icu_id"}}
    ],
    "administration_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "hospital_id"}}
    ],
    "quality_safety_metrics": [
        {"foreign_key": {"table_name": "departments", "column_name": "department_id"}}
    ],
    "finance_billing_metrics": [
        {"foreign_key": {"table_name": "hospitals", "column_name": "hospital_id"}}
    ],
    "patient_experience_metrics": [
        {"foreign_key": {"table_name": "hospitals", "column_name": "hospital_id"}}
    ],
    "departments": [
        {"foreign_key": {"table_name": "emergency_metrics", "column_name": "department_id"}},
        {"foreign_key": {"table_name": "inpatient_metrics", "column_name": "ward_id"}},
        {"foreign_key": {"table_name": "outpatient_metrics", "column_name": "clinic_id"}},
        {"foreign_key": {"table_name": "icu_metrics", "column_name": "icu_id"}},
        {"foreign_key": {"table_name": "hospital_administration_metrics", "column_name": "hospital_id"}},
        {"foreign_key": {"table_name": "patient_safety_metrics", "column_name": "department_id"}},
        {"foreign_key": {"table_name": "hospitals", "column_name": "hospital_id"}}
    ],
    "hospitals": [
        {"foreign_key": {"table_name": "financial_metrics", "column_name": "hospital_id"}},
        {"foreign_key": {"table_name": "patient_experience_metrics", "column_name": "hospital_id"}},
        {"foreign_key": {"table_name": "departments", "column_name": "hospital_id"}},
        {"foreign_key": {"table_name": "staff", "column_name": "hospital_id"}}
    ],
    "staff": [
        {"foreign_key": {"table_name": "hospitals", "column_name": "hospital_id"}}
    ]
}

# %%
table_metadata = []
for table_key, cols in dim_tables.items():
    table_name_cleaned = table_key.strip()
    meta_info = {key: None for key in keys_req}
    meta_info['table_name'] = table_name_mapping.get(table_name_cleaned)
    meta_info['description'] = table_description_mapping.get(table_name_cleaned)
    joins = join_metadata.get(table_name_cleaned, [])
    if joins:
        join_list = [f"{list(join.keys())[0]} → {list(join.values())[0]}" for join in joins]
        meta_info["joins"] = [", ".join(join_list)]
    else:
        meta_info["joins"] = []
    pk_info = primary_key_metadata.get(table_name_cleaned, [])

    meta_info['primary_key'] = [
        col
        for d in pk_info
        for col in (d["primary_key"] if isinstance(d["primary_key"], list) else [d["primary_key"]])
    ] if pk_info else []


    fk_info = foreign_key_metadata.get(table_name_cleaned, [])
    meta_info['foreign_key'] = [
        {
            "table_name": fk["foreign_key"]["table_name"],
            "column_name": fk["foreign_key"]["column_name"],
            "description": table_description_mapping.get(table_name_mapping_reversed.get(fk["foreign_key"]["table_name"]))
        }
        for fk in fk_info
    ] if fk_info else []
    roles_allowed = unique_combination[(unique_combination['source_sheet'] == table_key)]['roles'].tolist()
    print(f"Roles allowed for {table_key}: {roles_allowed}")
    #make it a simple list
    roles_allowed = [role for sublist in roles_allowed for role in sublist]
    meta_info['managers_allowed'] = "No"
    meta_info['administrative_staff_allowed'] = "No"
    meta_info['non_clinical_staff_allowed'] = "No"
    for role in roles_allowed:
        if role == "non_clinical_staff":
            meta_info['non_clinical_staff_allowed'] = "Yes"
        elif role == "manager":
            meta_info['managers_allowed'] = "Yes"
        elif role == "administrative_staff":
            meta_info['administrative_staff_allowed'] = "Yes"
    
    # if isinstance(meta_info['roles_allowed'], list) and len(meta_info['roles_allowed']) == 1:
    #     meta_info['roles_allowed'] = meta_info['roles_allowed'][0]
    table_metadata.append(meta_info)

print(table_metadata)
# Out:
# Roles allowed for departments: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for hospitals: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for staff: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for emergency_department_metrics: [array(['non_clinical_staff', 'manager', 'administrative_staff'],
#       dtype=object)]
# Roles allowed for inpatient_ward_metrics: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for outpatient_department_metrics: [array(['non_clinical_staff', 'manager', 'administrative_staff'],
#       dtype=object)]
# Roles allowed for surgery_department_metrics: [array(['non_clinical_staff', 'manager', 'administrative_staff'],
#       dtype=object)]
# Roles allowed for radiology_department_metrics: [array(['non_clinical_staff', 'manager', 'administrative_staff'],
#       dtype=object)]
# Roles allowed for laboratory_department_metrics: [array(['non_clinical_staff', 'manager'], dtype=object)]
# Roles allowed for pharmacy_department_metrics: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for  icu_metrics: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for  administration_metrics: [array(['manager', 'administrative_staff'], dtype=object)]
# Roles allowed for quality_safety_metrics: [array(['non_clinical_staff', 'manager', 'administrative_staff'],
#       dtype=object)]
# Roles allowed for finance_billing_metrics: [array(['non_clinical_staff', 'manager'], dtype=object)]
# Roles allowed for patient_experience_metrics: [array(['manager', 'administrative_staff'], dtype=object)]
# [{'table_name': 'departments', 'description': 'Information about various departments within the healthcare facility.', 'joins': ['departments.department_id → emergency_metrics.department_id, departments.department_id → inpatient_metrics.ward_id, departments.department_id → outpatient_metrics.clinic_id, departments.department_id → icu_metrics.icu_id, departments.department_id → hospital_administration_metrics.hospital_id, departments.department_id → patient_safety_metrics.department_id, departments.hospital_id → hospitals.hospital_id'], 'primary_key': ['department_id'], 'foreign_key': [{'table_name': 'emergency_metrics', 'column_name': 'department_id', 'description': 'Metrics related to the emergency department operations and performance.'}, {'table_name': 'inpatient_metrics', 'column_name': 'ward_id', 'description': 'Metrics related to inpatient ward operations and performance.'}, {'table_name': 'outpatient_metrics', 'column_name': 'clinic_id', 'description': 'Metrics related to outpatient department operations and performance.'}, {'table_name': 'icu_metrics', 'column_name': 'icu_id', 'description': 'Metrics related to intensive care unit operations and performance.'}, {'table_name': 'hospital_administration_metrics', 'column_name': 'hospital_id', 'description': 'Metrics related to hospital administration operations and performance.'}, {'table_name': 'patient_safety_metrics', 'column_name': 'department_id', 'description': 'Metrics related to patient safety and quality of care.'}, {'table_name': 'hospitals', 'column_name': 'hospital_id', 'description': 'Information about different hospitals and their facilities.'}], 'managers_allowed': 'Yes', 'administrative_staff_allowed': 'Yes', 'non_clinical_staff_allowed': 'No'}, {'table_name': 'hospitals', 'description': 'Information about different hospitals and their facilities.', 'joins': ['hospitals.hospital_id → financial_metrics.hospital_id, hospitals.hospital_id → patient_experience_metrics.hospital_id, hospitals.hospital_id → departments.hospital_id'], 'primary_key': ['hospital_id'], 'foreign_key': [{'table_name': 'financial_metrics', 'column_name': 'hospital_id', 'description': 'Metrics related to financial operations and billing processes.'}, {'table_name': 'patient_experience_metrics', 'column_name': 'hospital_id', 'description': 'Metrics related to patient experience and satisfaction.'}, {'table_name': 'departments', 'column_name': 'hospital_id', 'description': 'Information about various departments within the healthcare facility.'}, {'table_name': 'staff', 'column_name': 'hospital_id', 'description': 'Details about the healthcare staff including roles and responsibilities.'}], 'managers_allowed': 'Yes', 'administrative_staff_allowed': 'Yes', 'non_clinical_staff_allowed': 'No'}, {'table_name': 'staff', 'description': 'Details about the healthcare staff including roles and responsibilities.', 'joins': ['staff.hospital_id → hospitals.hospital_id'], 'primary_key': ['staff_id'], 'foreign_key': [{'table_name': 'hospitals', 'column_name': 'hospital_id', 'description': 'Information about different hospitals and their facilities.'}], 'managers_allowed': 'Yes', 'administrative_staff_allowed': 'Yes', 'non_clinical_staff_allowed': 'No'}, {'table_name': 'emergency_metrics', 'description': 'Metrics related to the emergency department operations and performance.', 'joins': ['departments.department_id → emergency_metrics.department_id'], 'primary_key': ['department_id', 'date'], 'foreign_key': [{'table_name': 'departments', 'column_name': 'department_id', 'description': 'Information about various departments within the healthcare facility.'}], 'managers_allowed': 'Yes', 'administrative_staff_allowed': 'Yes', 'non_clinical_staff_allowed': 'Yes'}, {'table_name': 'inpatient_metrics', 'description': 'Metrics related to inpatient ward operations and performance.', 'joins': ['departments.department_id → inpatient_metrics.ward_id'], 'primary_key': ['ward_id', 'date'], 'foreign_key': [{'table_name':  ...

# %%
df= pd.DataFrame(table_metadata)
df
# Out:
#                          table_name  \
# 0                       departments
# 1                         hospitals
# 2                             staff
# 3                 emergency_metrics
# 4                 inpatient_metrics
# 5                outpatient_metrics
# 6                   surgery_metrics
# 7                 radiology_metrics
# 8                       lab_metrics
# 9                  pharmacy_metrics
# 10                      icu_metrics
# 11  hospital_administration_metrics
# 12           patient_safety_metrics
# 13                financial_metrics
# 14       patient_experience_metrics
#
#                                           description  \
# 0   Information about various departments within t...
# 1   Information about different hospitals and thei...
# 2   Details about the healthcare staff including r...
# 3   Metrics related to the emergency department op...
# 4   Metrics related to inpatient ward operations a...
# 5   Metrics related to outpatient department opera...
# 6   Metrics related to surgery department operatio...
# 7   Metrics related to radiology department operat...
# 8   Metrics related to laboratory department opera...
# 9   Metrics related to pharmacy department operati...
# 10  Metrics related to intensive care unit operati...
# 11  Metrics related to hospital administration ope...
# 12  Metrics related to patient safety and quality ...
# 13  Metrics related to financial operations and bi...
# 14  Metrics related to patient experience and sati...
#
#                                                 joins  \
# 0   [departments.department_id → emergency_metrics...
# 1   [hospitals.hospital_id → financial_metrics.hos...
# 2         [staff.hospital_id → hospitals.hospital_id]
# 3   [departments.department_id → emergency_metrics...
# 4   [departments.department_id → inpatient_metrics...
# 5   [departments.department_id → outpatient_metric...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10   [departments.department_id → icu_metrics.icu_id]
# 11  [departments.department_id → hospital_administ...
# 12  [departments.department_id → patient_safety_me...
# 13  [hospitals.hospital_id → financial_metrics.hos...
# 14  [hospitals.hospital_id → patient_experience_me...
#
#                  primary_key  \
# 0            [department_id]
# 1              [hospital_id]
# 2                 [staff_id]
# 3      [department_id, date]
# 4            [ward_id, date]
# 5          [clinic_id, date]
# 6    [surgery_type_id, date]
# 7   [radiology_lab_id, date]
# 8             [lab_id, date]
# 9        [pharmacy_id, date]
# 10            [icu_id, date]
# 11       [hospital_id, date]
# 12     [department_id, date]
# 13       [hospital_id, date]
# 14       [hospital_id, date]
#
#                                           foreign_key managers_allowed  \
# 0   [{'table_name': 'emergency_metrics', 'column_n...              Yes
# 1   [{'table_name': 'financial_metrics', 'column_n...              Yes
# 2   [{'table_name': 'hospitals', 'column_name': 'h...              Yes
# 3   [{'table_name': 'departments', 'column_name': ...              Yes
# 4   [{'table_name': 'departments', 'column_name': ...              Yes
# 5   [{'table_name': 'departments', 'column_name': ...              Yes
# 6                                                  []              Yes
# 7                                                  []              Yes
# 8                                                  []              Yes
# 9                                                  []              Yes
# 10  [{'table_name': 'departments', 'column_name': ...              Yes
# 11  [{'table_name': 'departments', 'column_name': ...              Yes
# 12  [{'table_name': 'departments', 'column_name': ...              Yes
# 13  [{'table_name': 'hospitals', 'column_name': 'h...              Yes
# 14  [{'table_name': 'hospitals', 'column_name': 'h...              Yes
#
#    administrative_staff_allowed non_clinical_staff_allowed
# 0                           Yes                         No
# 1                           Yes                         No
# 2                           Yes                         No
# 3                           Yes                        Yes
# 4                           Yes                         No
# 5                           Yes                        Yes
# 6                           Yes                        Yes
# 7                           Yes                        Yes
# 8                            No                        Yes
# 9                           Yes                         No
# 10                          Yes                         No
# 11                          Yes                         No
# 12                          Yes                        Yes
# 13                           No                        Yes
# 14                          Yes                         No

# %%
for i, item in enumerate(table_metadata):
    if isinstance(item, dict):
        for key, value in item.items():
            if isinstance(value, np.ndarray):
                item[key] = value.tolist()
    elif isinstance(item, np.ndarray):
        table_metadata[i] = item.tolist()

# Convert any numpy arrays in the DataFrame to lists before dumping to JSON
def convert_ndarray_to_list(x):
    if isinstance(x, np.ndarray):
        return x.tolist()
    return x

df_serializable = df.applymap(convert_ndarray_to_list)

with open("table_level_metadata.json", "w", encoding="utf-8") as f:
    json.dump(df_serializable.to_dict(orient="records"), f, indent=4, ensure_ascii=False)
# Out:
# /tmp/ipykernel_258005/3611264278.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_serializable = df.applymap(convert_ndarray_to_list)
